# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file='/home/dell/GIT_REPO/intro-to-ml-with-python/week5/data/diabetes.csv' #relative path. So in present working directory it will look for data folder.

df=pd.read_csv(file) #read_csv is a function in pandas.

print(df.shape)
df.head(5)
# Out:
# (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df[df.columns[:8]].hist(figsize=(10,10));

# %%
df["Age"].hist()

# %%
df.Age.hist()

# %%
fig,ax = plt.subplots(4,2,figsize=(16,16))
